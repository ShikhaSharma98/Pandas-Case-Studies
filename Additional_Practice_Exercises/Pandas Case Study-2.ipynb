# %%
import pandas as pd

# %% [markdown]
# ### 1.Create sub set of cust_demo as “cust_s1” with ID, age, Gender and Location variables using the condition marital_status = “Married” and Own_house = 1 and age>28.

# %%
cust_demo=pd.read_csv("Cust_demo.csv")
cust_demo.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    NumberOfDependents  Own_House  No_Years_address
# 0                 1.0          1                 3
# 1                 0.0          0                 3
# 2                 0.0          0                 2
# 3                 1.0          1                 1
# 4                 1.0          0                 3

# %%
cust_s1=cust_demo.loc[(cust_demo.Martial_Status=='Married')&(cust_demo.Own_House==1)&(cust_demo.age>28),['ID', 'age', 'Gender','Location']].reset_index()
cust_s1.head()
# Out:
#    index      ID  age  Gender                   Location
# 0     28   26404   33       0        Kolkata,West Bengal
# 1     42  137858   34       0         Chennai,Tamil Nadu
# 2     50   57715   39       1  Thiruvananthapuram,Kerala
# 3     52   76230   53       1         Chandigarh,Haryana
# 4     56    8493   78       1           Ranchi,Jharkhand

# %% [markdown]
# ### 2.Sort the cust_s1 dataset using location in ascending order and age in descending order with in the  location.

# %%
cust_s1.sort_values(by=['Location','age'],ascending=[True,False])
# Out:
#         index      ID  age  Gender                   Location
# 9182    83512  106073   90       1           Agartala,Tripura
# 5345    49124    8967   88       1           Agartala,Tripura
# 7126    65242   44249   87       1           Agartala,Tripura
# 16299  148381   28287   86       0           Agartala,Tripura
# 7019    64155   60165   85       0           Agartala,Tripura
# 16223  147738   22031   85       1           Agartala,Tripura
# 9929    90405   87535   84       0           Agartala,Tripura
# 11604  105693   59383   84       1           Agartala,Tripura
# 12057  109795    8645   84       1           Agartala,Tripura
# 16409  149431   18627   84       0           Agartala,Tripura
# 4769    43491   87397   82       0           Agartala,Tripura
# 6074    55891   92549   82       1           Agartala,Tripura
# 3648    33226  145495   81       1           Agartala,Tripura
# 4777    43577  135697   81       1           Agartala,Tripura
# ...

# %% [markdown]
# ### 3.Rename the variable “NumberOfDependents” as “No_of_dependents” in cust_demo data.

# %%
cust_demo.rename(columns={'NumberOfDependents':'No_of_dependents'},inplace=True)
cust_demo.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    No_of_dependents  Own_House  No_Years_address
# 0               1.0          1                 3
# 1               0.0          0                 3
# 2               0.0          0                 2
# 3               1.0          1                 1
# 4               1.0          0                 3

# %% [markdown]
# ### 4.Remove duplicates from the both data sets Cust_data & Cust_Demo

# %%
cust_data=pd.read_csv('Cust_data.csv')
cust_data.head()
# Out:
#        ID  SeriousDlqin2yrs  RevolvingUtilization  No_of_30_59_DPD  DebtRatio  \
# 0   83236                 0              0.311726                0   0.296409
# 1    2503                 0              0.124988                0   0.115903
# 2  137013                 0              0.060258                0   0.515147
# 3   51306                 0              0.064322                0   0.165127
# 4   71937                 0              0.211186                0   0.022283
#
#    MonthlyIncome  No_Of_OpenCreditLines  No_of_90_DPD  No_of_RealEstateLoans  \
# 0        11500.0                     12             0                      3
# 1        14166.0                     13             0                      1
# 2         6733.0                      7             0                      3
# 3        13316.0                     10             0                      1
# 4         2557.0                      3             0                      0
#
#    No_of_60_89_DPD
# ...

# %%
cust_demo.drop_duplicates(inplace=True)

# %%
cust_data.drop_duplicates(inplace=True)

# %% [markdown]
# ### 5.Create new variable as “No_of_30_plus_DPD = No_of_30_59_DPD+No_of_90_DPD+No_of_60_89_DPD”,           “No_of_60_plus_DPD = No_of_90_DPD+ No_of_60_89_DPD” in cust_data

# %%
cust_data=cust_data.assign(No_of_30_plus_DPD=cust_data.No_of_30_59_DPD+cust_data.No_of_60_89_DPD+cust_data.No_of_90_DPD,
                 No_of_60_plus_DPD=cust_data.No_of_60_89_DPD+cust_data.No_of_90_DPD)
cust_data.tail()
# Out:
#             ID  SeriousDlqin2yrs  RevolvingUtilization  No_of_30_59_DPD  \
# 149897  148580                 1              1.000000                1
# 149898   93517                 0              0.163864                0
# 149899   15481                 0              0.031732                0
# 149900   50464                 0              0.078050                0
# 149901   75766                 0              0.075823                0
#
#         DebtRatio  MonthlyIncome  No_Of_OpenCreditLines  No_of_90_DPD  \
# 149897   0.021124         2650.0                      0             0
# 149898   1.276108         1962.0                      9             0
# 149899   0.260058        10016.0                     12             0
# 149900   0.569960         1750.0                     10             0
# 149901   0.182163        12400.0                      3             0
#
#         No_of_RealEstateLoans  No_of_60_89_DPD  No_of_30_plus_DPD  \
# ...

# %% [markdown]
# ### 6.Perform below joins between cust_data & cust_demo.
# #### a. Create data set “cust_leftjoin” using Left Join
# #### b. Create data set “cust_rightjoin” using right Join
# #### c. Create data set “cust_innterjoin” using inner Join
# #### d. Create data set “cust_fulljoin” using full Join

# %%
cust_leftjoin=pd.merge(cust_demo,cust_data,on='ID',how='left')
cust_leftjoin.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    No_of_dependents  Own_House  No_Years_address  SeriousDlqin2yrs  \
# 0               1.0          1                 3               0.0
# 1               0.0          0                 3               0.0
# 2               0.0          0                 2               0.0
# 3               1.0          1                 1               0.0
# 4               1.0          0                 3               1.0
#
#    RevolvingUtilization  No_of_30_59_DPD  DebtRatio  MonthlyIncome  \
# 0              1.158218              0.0   0.257593         2600.0
# ...

# %%
cust_rightjoin=pd.merge(cust_demo,cust_data,on='ID',how='right')
cust_rightjoin.head()
# Out:
#        ID                  Location  Gender   age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat     0.0  39.0         Single
# 1  148736  Hyderabad,Andhra Pradesh     0.0  52.0        Married
# 2   95965   Shimla,Himachal Pradesh     0.0  62.0        Married
# 3   61759               Srinagar,JK     0.0  42.0         Single
# 4   49806            Imphal,Manipur     0.0  41.0         Single
#
#    No_of_dependents  Own_House  No_Years_address  SeriousDlqin2yrs  \
# 0               1.0        1.0               3.0                 0
# 1               0.0        0.0               3.0                 0
# 2               0.0        0.0               2.0                 0
# 3               1.0        1.0               1.0                 0
# 4               1.0        0.0               3.0                 1
#
#    RevolvingUtilization  No_of_30_59_DPD  DebtRatio  MonthlyIncome  \
# 0              1.158218                0   0.257593         2600.0
# ...

# %%
cust_innerjoin=pd.merge(cust_demo,cust_data,on='ID',how='inner')
cust_innerjoin.head()
# Out:
#        ID                  Location  Gender  age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat       0   39         Single
# 1  148736  Hyderabad,Andhra Pradesh       0   52        Married
# 2   95965   Shimla,Himachal Pradesh       0   62        Married
# 3   61759               Srinagar,JK       0   42         Single
# 4   49806            Imphal,Manipur       0   41         Single
#
#    No_of_dependents  Own_House  No_Years_address  SeriousDlqin2yrs  \
# 0               1.0          1                 3                 0
# 1               0.0          0                 3                 0
# 2               0.0          0                 2                 0
# 3               1.0          1                 1                 0
# 4               1.0          0                 3                 1
#
#    RevolvingUtilization  No_of_30_59_DPD  DebtRatio  MonthlyIncome  \
# 0              1.158218                0   0.257593         2600.0
# ...

# %%
cust_fulljoin=pd.merge(cust_demo,cust_data,on='ID',how='outer')
cust_fulljoin.head()
# Out:
#        ID                  Location  Gender   age Martial_Status  \
# 0    4532       Gandhinagar,Gujarat     0.0  39.0         Single
# 1  148736  Hyderabad,Andhra Pradesh     0.0  52.0        Married
# 2   95965   Shimla,Himachal Pradesh     0.0  62.0        Married
# 3   61759               Srinagar,JK     0.0  42.0         Single
# 4   49806            Imphal,Manipur     0.0  41.0         Single
#
#    No_of_dependents  Own_House  No_Years_address  SeriousDlqin2yrs  \
# 0               1.0        1.0               3.0               0.0
# 1               0.0        0.0               3.0               0.0
# 2               0.0        0.0               2.0               0.0
# 3               1.0        1.0               1.0               0.0
# 4               1.0        0.0               3.0               1.0
#
#    RevolvingUtilization  No_of_30_59_DPD  DebtRatio  MonthlyIncome  \
# 0              1.158218              0.0   0.257593         2600.0
# ...

# %% [markdown]
# ### 7.Create two data sets by taking random sample from cust_demo with 5% data in first data set and 10000 observations in second data set

# %%
cust_demo_5per=cust_demo.sample(frac=.05)
cust_demo_5per
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 65877    68384                    Jammu,JK       0   36         Single
# 121567   72072              Aizawl,Mizoram       0   40        Married
# 130251   34588          Chennai,Tamil Nadu       1   64         Single
# 50638    18409     Shimla,Himachal Pradesh       0   79         Single
# 130769   91813            Agartala,Tripura       0   67         Single
# 47684    71764                 Patna,Bihar       0   40        Married
# 1949     64662       Bhopal,Madhya Pradesh       1   57         Single
# 40034    23516                 Srinagar,JK       0   51         Single
# 29915    77802              Aizawl,Mizoram       0   52         Single
# 116676   61932              Aizawl,Mizoram       0   36         Single
# 40843    58974  Itanagar,Arunachal Pradesh       0   61         Single
# 111957   27477       Bhopal,Madhya Pradesh       0   72        Married
# ...

# %%
cust_demo_10k=cust_demo.sample(n=1000)
cust_demo_10k
# Out:
#             ID                    Location  Gender  age Martial_Status  \
# 132394  104130       Bhopal,Madhya Pradesh       0   46         Single
# 133502   16789        Dehradun,Uttarakhand       0   50         Single
# 2671     29090    Hyderabad,Andhra Pradesh       0   68         Single
# 67094    84103       Bhopal,Madhya Pradesh       1   39         Single
# 10117    32460         Bangalore,Karnataka       0   81         Single
# 24151    79405     Shimla,Himachal Pradesh       0   35         Single
# 74223     3508            Ranchi,Jharkhand       0   57         Single
# 54915    96024         Raipur,Chhattisgarh       0   54         Single
# 61545    26997              Gangtok,Sikkim       0   68         Single
# 68235    39162              Aizawl,Mizoram       0   43         Single
# 81207    13831   Thiruvananthapuram,Kerala       1   60         Single
# 138471   13581                    Jammu,JK       1   41         Single
# ...

# %% [markdown]
# ### 8.Calculate “number of customers” and “number of married customer” using combined data set comes from left join of cust_data and cust_demo

# %%
cust_leftjoin.head()
print("Number of Customers : ",cust_leftjoin.ID.count())
print("Number of married Customers : ", cust_leftjoin[cust_leftjoin.Martial_Status=='Married'].ID.count())
# Out:
# Number of Customers :  149956
# Number of married Customers :  42845

# %% [markdown]
# ### 9. Create summary report with below column by combination of Gender, Serious_delinquency.
# #### a. Number of customers
# #### b. Percentage of customers
# #### c. Average Revolving utilization
# #### d. Standard deviation with in the utilization
# #### e. Average monthly income
# #### f. Maximum Monthly income
# #### g. Standard deviation with in the income
# #### h. Average Age
# #### i. Average Dependents

# %%
avg=cust_innerjoin[['Gender','SeriousDlqin2yrs','RevolvingUtilization','MonthlyIncome','age','No_of_dependents']].groupby(['Gender','SeriousDlqin2yrs']).agg('mean').add_prefix('avg_')
avg
# Out:
#                          avg_RevolvingUtilization  avg_MonthlyIncome  \
# Gender SeriousDlqin2yrs
# 0      0                                 7.279863        6676.964828
#        1                                 5.295516        5522.818565
# 1      0                                 4.332912        6866.835622
#        1                                 2.813082        5811.826739
#
#                            avg_age  avg_No_of_dependents
# Gender SeriousDlqin2yrs
# 0      0                 52.750403              0.743642
#        1                 45.684110              0.929393
# 1      0                 52.754413              0.742653
#        1                 46.335300              0.981426

# %%
count=cust_innerjoin[['Gender','SeriousDlqin2yrs','ID']].groupby(['Gender','SeriousDlqin2yrs']).agg('count').add_prefix('count_')
count
# Out:
#                          count_ID
# Gender SeriousDlqin2yrs
# 0      0                    87381
#        1                     6287
# 1      0                    52462
#        1                     3728

# %%
std=cust_innerjoin[['Gender','SeriousDlqin2yrs','RevolvingUtilization','MonthlyIncome']].groupby(['Gender','SeriousDlqin2yrs']).agg('std').add_prefix('std_')
std
# Out:
#                          std_RevolvingUtilization  std_MonthlyIncome
# Gender SeriousDlqin2yrs
# 0      0                               288.877443        8950.773701
#        1                               145.701505        4669.707578
# 1      0                               189.815316       21260.060839
#        1                               104.605013        8077.034775

# %%
max_=cust_innerjoin[['Gender','SeriousDlqin2yrs','MonthlyIncome']].groupby(['Gender','SeriousDlqin2yrs']).agg('max').add_prefix('max_')
max_
# Out:
#                          max_MonthlyIncome
# Gender SeriousDlqin2yrs
# 0      0                          835040.0
#        1                           81000.0
# 1      0                         3008750.0
#        1                          250000.0

# %%
per=count.groupby(level=0).apply(lambda x: x/x.sum() * 100)
per.rename(columns={'count_ID':'percentage_cust'},inplace=True)
per
# Out:
#                          percentage_cust
# Gender SeriousDlqin2yrs
# 0      0                       93.287996
#        1                        6.712004
# 1      0                       93.365368
#        1                        6.634632

# %%
#Summary_Report
pd.concat([avg,count,std,max_,per],axis=1)
# Out:
#                          avg_RevolvingUtilization  avg_MonthlyIncome  \
# Gender SeriousDlqin2yrs
# 0      0                                 7.279863        6676.964828
#        1                                 5.295516        5522.818565
# 1      0                                 4.332912        6866.835622
#        1                                 2.813082        5811.826739
#
#                            avg_age  avg_No_of_dependents  count_ID  \
# Gender SeriousDlqin2yrs
# 0      0                 52.750403              0.743642     87381
#        1                 45.684110              0.929393      6287
# 1      0                 52.754413              0.742653     52462
#        1                 46.335300              0.981426      3728
#
#                          std_RevolvingUtilization  std_MonthlyIncome  \
# Gender SeriousDlqin2yrs
# 0      0                               288.877443        8950.773701
# ...

# %% [markdown]
# ### 10.Create summary report with below information
# #### a. Number of married customers
# #### b. Percentage of married customers

# %%
married_cust=cust_innerjoin[['Martial_Status','ID']].groupby('Martial_Status').count()
married_cust.rename(columns={'ID':'No_of_Married_customers'},inplace=True)
percentage_married_cust=married_cust.groupby(level=0).apply(lambda x: x/cust_innerjoin.Martial_Status.notna().sum() * 100)
percentage_married_cust.rename(columns={'ID':'percentage_of_married_cust'},inplace=True)

# %%
pd.concat([married_cust,percentage_married_cust],axis=1)
# Out:
#                 No_of_Married_customers  No_of_Married_customers
# Martial_Status
# Married                           42819                28.573049
# Single                           107039                71.426951
